# %% [markdown]
# # UN Sustainable Development Goals
#
# This notebook implements the pre-processing needed for importing the UN SDG dataset into OWID's grapher database.
# A rough outline of the process:
#
#   1. **Load the dataset exported from the UN SDG Indicators database website**
#   1. **Replace the codes used in dimensions with their full names from the codelists**
#   1. **Export the entities (countries) used in the dataset**
#   1. **Export all the data as datasets, variables and datapoints**

# %%
import pandas as pd
import numpy as np
import collections
import itertools
import functools
import requests
import json
import math
from datetime import datetime
from tqdm import tqdm

from import_metadata import extract_description

pd.options.display.max_columns = None
pd.set_option('display.max_colwidth', -1)

# %% [markdown]
# ## Load the data
#
# The data was obtained from the [UN SDG Indicators database](https://unstats.un.org/sdgs/indicators/database). We selected all _Goals_ (topmost category in the classification of indicators) and requested the entire dataset.

# %%
def str_to_float(s):
    try:
        # Parse strings with thousands (,) separators
        return float(s.replace(',','')) if type(s) == str else s
    except ValueError:
        return None

# %%
original_df = pd.read_csv(
    "data/20190903150325064_drifter4e@gmail.com_data.csv", 
    converters={'Value': str_to_float},
    low_memory=False
)

# %% [markdown]
# Remove entries for which no value exists.

# %%
original_df = original_df[original_df['Value'].notnull()]

# %% [markdown]
# ## Structure & plan
#
# Some terminology:
#
# - **Dimensions**: The column names wrapped in square brackets (`[]`) are _dimensions_ of the dataset. For example, `[Age]` is a dimension.
# - **Dimension entities**: A value in a dimension column is a _dimension entity_. For example, `15-24` is an entity within the `[Age]` dimension.
#
# In addition, there is a _geographical_ dimension and a _time_ dimension in this dataset – those are special dimensions and we won't call them "dimensions", only columns wrapped in `[]` will be called dimensions.
#
# How we will organise the exports:
#
# - For each unique `SeriesCode` we will create a **dataset**.
# - For each `SeriesCode` and a unique combination of dimension entities we will construct a **variable**. So for example, `(SeriesCode: SI_POV_EMP1, Age: 15-14, Sex: MALE)` will form one variable. Remember, `Age` and `Sex` are dimensions, `15-24` and `MALE` are dimension entities. If a some `SeriesCode` doesn't have any corresponding dimensions (they are `NaN`) then there is only a single variable for that `SeriesCode`.
# - For each variable, we will create a **datapoints** file that contains the values broken down by geography and year. So it would have 3 columns: `geo`, `year` and `value`. The variable id will be derived from the filename (`datapoints_[variable_id]`).
# - We will create an **entities** file containing all possible geo entities.

# %%
# A section of the dataset that contains Age and Sex dimension entities
original_df[original_df['[Age]'].notnull() & original_df['[Sex]'].notnull()]
# Out:
#          Goal Target Indicator    SeriesCode  \
# 1822     1     1.1    1.1.1     SI_POV_EMP1
# 1823     1     1.1    1.1.1     SI_POV_EMP1
# 1824     1     1.1    1.1.1     SI_POV_EMP1
# 1825     1     1.1    1.1.1     SI_POV_EMP1
# 1826     1     1.1    1.1.1     SI_POV_EMP1
# 1827     1     1.1    1.1.1     SI_POV_EMP1
# 1828     1     1.1    1.1.1     SI_POV_EMP1
# 1829     1     1.1    1.1.1     SI_POV_EMP1
# 1830     1     1.1    1.1.1     SI_POV_EMP1
# 1831     1     1.1    1.1.1     SI_POV_EMP1
# 1832     1     1.1    1.1.1     SI_POV_EMP1
# 1833     1     1.1    1.1.1     SI_POV_EMP1
# 1834     1     1.1    1.1.1     SI_POV_EMP1
# 1835     1     1.1    1.1.1     SI_POV_EMP1
# 1836     1     1.1    1.1.1     SI_POV_EMP1
# 1837     1     1.1    1.1.1     SI_POV_EMP1
# 1838     1     1.1    1.1.1     SI_POV_EMP1
# 1839     1     1.1    1.1.1     SI_POV_EMP1
# 1840     1     1.1    1.1.1     SI_POV_EMP1
# 1841     1     1.1    1.1.1     SI_POV_EMP1
# 1842     1     1.1    1.1.1     SI_POV_EMP1
# 1843     1     1.1    1.1.1     SI_POV_EMP1
# 1844     1     1.1    1.1.1     SI_POV_EMP1
# 1845     1     1.1    1.1.1     SI_POV_EMP1
# 1846     1     1.1    1.1.1     SI_POV_EMP1
# 1847     1     1.1    1.1.1     SI_POV_EMP1
# 1848     1     1.1    1.1.1     SI_POV_EMP1
# 1849     1     1.1    1.1.1     SI_POV_EMP1
# 1850     1     1.1    1.1.1     SI_POV_EMP1
# 1851     1     1.1    1.1.1     SI_POV_EMP1
# ...     ..     ...      ...             ...
# 1152765  16    16.2   16.2.3    VC_VAW_SXVLN
# 1152766  16    16.2   16.2.3    VC_VAW_SXVLN
# 1152767  16    16.2   16.2.3    VC_VAW_SXVLN
# 1152768  16    16.2   16.2.3    VC_VAW_SXVLN
# 1152769  16    16.2   16.2.3    VC_VAW_SXVLN
# 1152770  16    16.2   16.2.3    VC_VAW_SXVLN
# 1152771  16    16.2   16.2.3    VC_VAW_SXVLN
# 1152772  16    16.2   16.2.3    VC_VAW_SXVLN
# 1152773  16    16.2   16.2.3    VC_VAW_SXVLN
# 1152774  16    16.2   16.2.3    VC_VAW_SXVLN
# 1152775  16    16.2   16.2.3    VC_VAW_SXVLN
# 1152776  16    16.2   16.2.3    VC_VAW_SXVLN
# 1152777  16    16.2   16.2.3    VC_VAW_SXVLN
# 1152778  16    16.2   16.2.3    VC_VAW_SXVLN
# 1152779  16    16.2   16.2.3    VC_VAW_SXVLN
# 1152780  16    16.2   16.2.3    VC_VAW_SXVLN
# 1152781  16    16.2   16.2.3    VC_VAW_SXVLN
# 1152782  16    16.2   16.2.3    VC_VAW_SXVLN
# 1152783  16    16.2   16.2.3    VC_VAW_SXVLN
# 1152784  16    16.2   16.2.3    VC_VAW_SXVLN
# 1152785  16    16.2   16.2.3    VC_VAW_SXVLN
# 1152786  16    16.2   16.2.3    VC_VAW_SXVLN
# 1152787  16    16.2   16.2.3    VC_VAW_SXVLN
# 1152788  16    16.2   16.2.3    VC_VAW_SXVLN
# 1152789  16    16.2   16.2.3    VC_VAW_SXVLN
# 1152790  16    16.2   16.2.3    VC_VAW_SXVLN
# 1152791  16    16.2   16.2.3    VC_VAW_SXVLN
# 1152792  16    16.2   16.2.3    VC_VAW_SXVLN
# 1152793  16    16.2   16.2.3    VC_VAW_SXVLN
# 1152794  16    16.2   16.2.3    VC_VAW_SXVLN
#
#                                                                                                                 SeriesDescription  \
# 1822     Employed population below international poverty line, by sex and age (%)
# 1823     Employed population below international poverty line, by sex and age (%)
# 1824     Employed population below international poverty line, by sex and age (%)
# 1825     Employed population below international poverty line, by sex and age (%)
# 1826     Employed population below international poverty line, by sex and age (%)
# 1827     Employed population below international poverty line, by sex and age (%)
# 1828     Employed population below international poverty line, by sex and age (%)
# 1829     Employed population below international poverty line, by sex and age (%)
# 1830     Employed population below international poverty line, by sex and age (%)
# 1831     Employed population below international poverty line, by sex and age (%)
# 1832     Employed population below international poverty line, by sex and age (%)
# 1833     Employed population below international poverty line, by sex and age (%)
# 1834     Employed population below international poverty line, by sex and age (%)
# 1835     Employed population below international poverty line, by sex and age (%)
# 1836     Employed population below international poverty line, by sex and age (%)
# 1837     Employed population below international poverty line, by sex and age (%)
# 1838     Employed population below international poverty line, by sex and age (%)
# 1839     Employed population below international poverty line, by sex and age (%)
# 1840     Employed population below international poverty line, by sex and age (%)
# 1841     Employed population below international poverty line, by sex and age (%)
# 1842     Employed population below international poverty line, by sex and age (%)
# 1843     Employed population below international poverty line, by sex and age (%)
# 1844     Employed population below international poverty line, by sex and age (%)
# 1845     Employed population below international poverty line, by sex and age (%)
# 1846     Employed population below international poverty line, by sex and age (%)
# 1847     Employed population below international poverty line, by sex and age (%)
# 1848     Employed population below international poverty line, by sex and age (%)
# 1849     Employed population below international poverty line, by sex and age (%)
# 1850     Employed population below international poverty line, by sex and age (%)
# 1851     Employed population below international poverty line, by sex and age (%)
# ...                                                                           ...
# 1152765  Proportion of population aged 18-29 years who experienced sexual violence by age 18, by sex (% of population aged 18-29)
# 1152766  Proportion of population aged 18-29 years who experienced sexual violence by age 18, by sex (% of population aged 18-29)
# 1152767  Proportion of population aged 18-29 years who experienced sexual violence by age 18, by sex (% of population aged 18-29)
# 1152768  Proportion of population aged 18-29 years who experienced sexual violence by age 18, by sex (% of population aged 18-29)
# 1152769  Proportion of population aged 18-29 years who experienced sexual violence by age 18, by sex (% of population aged 18-29)
# 1152770  Proportion of population aged 18-29 years who experienced sexual violence by age 18, by sex (% of population aged 18-29)
# 1152771  Proportion of population aged 18-29 years who experienced sexual violence by age 18, by sex (% of population aged 18-29)
# 1152772  Proportion of population aged 18-29 years who experienced sexual violence by age 18, by sex (% of population aged 18-29)
# 1152773  Proportion of population aged 18-29 years who experienced sexual violence by age 18, by sex (% of population aged 18-29)
# 1152774  Proportion of population aged 18-29 years who experienced sexual violence by age 18, by sex (% of population aged 18-29)
# 1152775  Proportion of population aged 18-29 years who experienced sexual violence by age 18, by sex (% of population aged 18-29)
# 1152776  Proportion of population aged 18-29 years who experienced sexual violence by age 18, by sex (% of population aged 18-29)
# 1152777  Proportion of population aged 18-29 years who experienced sexual violence by age 18, by sex (% of population aged 18-29)
# 1152778  Proportion of population aged 18-29 years who experienced sexual violence by age 18, by sex (% of population aged 18-29)
# 1152779  Proportion of population aged 18-29 years who experienced sexual violence by age 18, by sex (% of population aged 18-29)
# 1152780  Proportion of population aged 18-29 years who experienced sexual violence by age 18, by sex (% of population aged 18-29)
# 1152781  Proportion of population aged 18-29 years who experienced sexual violence by age 18, by sex (% of population aged 18-29)
# 1152782  Proportion of population aged 18-29 years who experienced sexual violence by age 18, by sex (% of population aged 18-29)
# 1152783  Proportion of population aged 18-29 years who experienced sexual violence by age 18, by sex (% of population aged 18-29)
# 1152784  Proportion of population aged 18-29 years who experienced sexual violence by age 18, by sex (% of population aged 18-29)
# 1152785  Proportion of population aged 18-29 years who experienced sexual violence by age 18, by sex (% of population aged 18-29)
# 1152786  Proportion of population aged 18-29 years who experienced sexual violence by age 18, by sex (% of population aged 18-29)
# 1152787  Proportion of population aged 18-29 years who experienced sexual violence by age 18, by sex (% of population aged 18-29)
# 1152788  Proportion of population aged 18-29 years who experienced sexual violence by age 18, by sex (% of population aged 18-29)
# 1152789  Proportion of population aged 18-29 years who experienced sexual violence by age 18, by sex (% of population aged 18-29)
# 1152790  Proportion of population aged 18-29 years who experienced sexual violence by age 18, by sex (% of population aged 18-29)
# 1152791  Proportion of population aged 18-29 years who experienced sexual violence by age 18, by sex (% of population aged 18-29)
# 1152792  Proportion of population aged 18-29 years who experienced sexual violence by age 18, by sex (% of population aged 18-29)
# 1152793  Proportion of population aged 18-29 years who experienced sexual violence by age 18, by sex (% of population aged 18-29)
# 1152778  9.907455   2014-15
# 1152779  0.100349   2014-15
# 1152780  3.378896   2008-09
# 1152781  2.100000   2017
# 1152782  0.386022   2013
# 1152783  1.835954   2013
# 1152784  5.862319   2015
# 1152785  4.000000   2012
# 1152786  13.000000  2012
# 1152787  0.000000   2017
# 1152788  3.784099   2013-14
# 1152789  24.800000  2017
# 1152790  5.200000   2016
# 1152791  1.300000   2016
# 1152792  1.840065   2007
# 1152793  7.300308   2015-16
# 1152794  5.474882   2013-14
#
#                                                                                                                                                                           Source  \
# 1822     ILO estimates, November 2018, available in ILOSTAT (www.ilo.org/ilostat). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.
# 1823     ILO estimates, November 2018, available in ILOSTAT (www.ilo.org/ilostat). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.
# 1824     ILO estimates, November 2018, available in ILOSTAT (www.ilo.org/ilostat). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.
# 1825     ILO estimates, November 2018, available in ILOSTAT (www.ilo.org/ilostat). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.
# 1826     ILO estimates, November 2018, available in ILOSTAT (www.ilo.org/ilostat). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.
# 1827     ILO estimates, November 2018, available in ILOSTAT (www.ilo.org/ilostat). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.
# 1828     ILO estimates, November 2018, available in ILOSTAT (www.ilo.org/ilostat). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.
# 1829     ILO estimates, November 2018, available in ILOSTAT (www.ilo.org/ilostat). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.
# 1830     ILO estimates, November 2018, available in ILOSTAT (www.ilo.org/ilostat). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.
# 1831     ILO estimates, November 2018, available in ILOSTAT (www.ilo.org/ilostat). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.
# 1832     ILO estimates, November 2018, available in ILOSTAT (www.ilo.org/ilostat). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.
# 1833     ILO estimates, November 2018, available in ILOSTAT (www.ilo.org/ilostat). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.
# 1834     ILO estimates, November 2018, available in ILOSTAT (www.ilo.org/ilostat). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.
# 1835     ILO estimates, November 2018, available in ILOSTAT (www.ilo.org/ilostat). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.
# 1836     ILO estimates, November 2018, available in ILOSTAT (www.ilo.org/ilostat). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.
# 1837     ILO estimates, November 2018, available in ILOSTAT (www.ilo.org/ilostat). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.
# 1838     ILO estimates, November 2018, available in ILOSTAT (www.ilo.org/ilostat). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.
# 1839     ILO estimates, November 2018, available in ILOSTAT (www.ilo.org/ilostat). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.
# 1840     ILO estimates, November 2018, available in ILOSTAT (www.ilo.org/ilostat). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.
# 1841     ILO estimates, November 2018, available in ILOSTAT (www.ilo.org/ilostat). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.
# 1842     ILO estimates, November 2018, available in ILOSTAT (www.ilo.org/ilostat). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.
# 1843     ILO estimates, November 2018, available in ILOSTAT (www.ilo.org/ilostat). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.
# 1844     ILO estimates, November 2018, available in ILOSTAT (www.ilo.org/ilostat). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.
# 1845     ILO estimates, November 2018, available in ILOSTAT (www.ilo.org/ilostat). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.
# 1846     ILO estimates, November 2018, available in ILOSTAT (www.ilo.org/ilostat). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.
# 1847     ILO estimates, November 2018, available in ILOSTAT (www.ilo.org/ilostat). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.
# 1848     ILO estimates, November 2018, available in ILOSTAT (www.ilo.org/ilostat). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.
# 1849     ILO estimates, November 2018, available in ILOSTAT (www.ilo.org/ilostat). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.
# 1850     ILO estimates, November 2018, available in ILOSTAT (www.ilo.org/ilostat). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.
# 1851     ILO estimates, November 2018, available in ILOSTAT (www.ilo.org/ilostat). For the specific sources by country and the estimation methodology refer to ILOSTAT directly.
# ...                                                                                                                                                                          ...
# 1152765  DHS
# 1152766  DHS
# 1152767  DHS and other national surveys
# 1152768  DHS
# 1152769  DHS
# 1152770  AIS
# 1152771  AIS
# 1152772  DHS
# 1152773  DHS
# 1152774  DHS
# 1152775  ENASSER
# 1152776  DHS
# 1152777  DHS
# 1152778  DHS
# 1152779  DHS
# 1152780  DHS
# 1152781  Continuous DHS
# 1152782  DHS
# 1152783  DHS
# 1152784  DHS
# 1152785  A National Prevalence Study on Exposure to Violence among Women and Men and its Association to Health
# 1152786  A National Prevalence Study on Exposure to Violence among Women and Men and its Association to Health
# 1152787  DHS
# 1152788  DHS
# 1152789  National Women's and Health Survey for Trinidad and Tobago
# 1152790  DHS
# 1152791  DHS
# 1152792  DHS
# 1152793  DHS
# 1152794  DHS
#
#                                                                                                                FootNote  \
# 1822     NaN
# 1823     NaN
# 1824     NaN
# 1825     NaN
# 1826     NaN
# 1827     NaN
# 1828     NaN
# 1829     NaN
# 1830     NaN
# 1831     NaN
# 1832     NaN
# 1833     NaN
# 1834     NaN
# 1835     NaN
# 1836     NaN
# 1837     NaN
# 1838     NaN
# 1839     NaN
# 1840     NaN
# 1841     NaN
# 1842     NaN
# 1843     NaN
# 1844     NaN
# 1845     NaN
# 1846     NaN
# 1847     NaN
# 1848     NaN
# 1849     NaN
# 1850     NaN
# 1851     NaN
# ...      ...
# 1152765  NaN
# 1152766  NaN
# 1152767  Based on 13 countries with a population coverage of 66 per cent
# 1152768  NaN
# 1152769  NaN
# 1152770  NaN
# 1152771  NaN
# 1152772  NaN
# 1152773  NaN
# 1152774  NaN
# 1152775  NaN
# 1152776  NaN
# 1152777  NaN
# 1152778  NaN
# 1152779  NaN
# 1152780  NaN
# 1152781  NaN
# 1152782  NaN
# 1152783  NaN
# 1152784  NaN
# 1152785  Refers to experiences of completed or attempted forced sexual intercourse
# 1152786  Refers to experiences of completed or attempted forced sexual intercourse
# 1152787  NaN
# 1152788  NaN
# 1152789  Refers to experiences of either being touched sexually or made to do something sexual when she did not want to
# 1152790  NaN
# 1152791  NaN
# 1152792  NaN
# 1152793  NaN
# 1152794  NaN
#
#         Nature    Units  [Age] [Bounds] [Cities] [Disability status]  \
# 1822     M      PERCENT  15+    NaN      NaN      NaN
# 1823     M      PERCENT  15-24  NaN      NaN      NaN
# 1824     M      PERCENT  15-24  NaN      NaN      NaN
# 1825     M      PERCENT  15-24  NaN      NaN      NaN
# 1826     M      PERCENT  25+    NaN      NaN      NaN
# 1827     M      PERCENT  15+    NaN      NaN      NaN
# 1828     M      PERCENT  15+    NaN      NaN      NaN
# 1829     M      PERCENT  25+    NaN      NaN      NaN
# 1830     M      PERCENT  25+    NaN      NaN      NaN
# 1831     M      PERCENT  15+    NaN      NaN      NaN
# 1832     M      PERCENT  15+    NaN      NaN      NaN
# 1833     M      PERCENT  15-24  NaN      NaN      NaN
# 1834     M      PERCENT  15-24  NaN      NaN      NaN
# 1835     M      PERCENT  15-24  NaN      NaN      NaN
# 1836     M      PERCENT  25+    NaN      NaN      NaN
# 1837     M      PERCENT  25+    NaN      NaN      NaN
# 1838     M      PERCENT  25+    NaN      NaN      NaN
# 1839     M      PERCENT  15+    NaN      NaN      NaN
# 1840     M      PERCENT  25+    NaN      NaN      NaN
# 1841     M      PERCENT  15-24  NaN      NaN      NaN
# 1842     M      PERCENT  15-24  NaN      NaN      NaN
# 1843     M      PERCENT  15+    NaN      NaN      NaN
# 1844     M      PERCENT  15+    NaN      NaN      NaN
# 1845     M      PERCENT  15+    NaN      NaN      NaN
# 1846     M      PERCENT  15-24  NaN      NaN      NaN
# 1847     M      PERCENT  25+    NaN      NaN      NaN
# 1848     M      PERCENT  25+    NaN      NaN      NaN
# 1849     M      PERCENT  15+    NaN      NaN      NaN
# 1850     M      PERCENT  15+    NaN      NaN      NaN
# 1851     M      PERCENT  15+    NaN      NaN      NaN
# ...     ..          ...  ...    ...      ...      ...
# 1152765  CA     PERCENT  18-29  NaN      NaN      NaN
# 1152766  CA     PERCENT  18-29  NaN      NaN      NaN
# 1152767  E      PERCENT  18-29  NaN      NaN      NaN
# 1152768  CA     PERCENT  18-29  NaN      NaN      NaN
# 1152769  CA     PERCENT  18-29  NaN      NaN      NaN
# 1152770  CA     PERCENT  18-29  NaN      NaN      NaN
# 1152771  CA     PERCENT  18-29  NaN      NaN      NaN
# 1152772  CA     PERCENT  18-29  NaN      NaN      NaN
# 1152773  CA     PERCENT  18-29  NaN      NaN      NaN
# 1152774  CA     PERCENT  18-29  NaN      NaN      NaN
# 1152775  CA     PERCENT  18-29  NaN      NaN      NaN
# 1152776  CA     PERCENT  18-29  NaN      NaN      NaN
# 1152777  CA     PERCENT  18-29  NaN      NaN      NaN
# 1152778  CA     PERCENT  18-29  NaN      NaN      NaN
# 1152779  CA     PERCENT  18-29  NaN      NaN      NaN
# 1152780  CA     PERCENT  18-29  NaN      NaN      NaN
# 1152781  CA     PERCENT  18-29  NaN      NaN      NaN
# 1152782  CA     PERCENT  18-29  NaN      NaN      NaN
# 1152783  CA     PERCENT  18-29  NaN      NaN      NaN
# 1152784  CA     PERCENT  18-29  NaN      NaN      NaN
# 1152785  C      PERCENT  18-74  NaN      NaN      NaN
# 1152786  C      PERCENT  18-74  NaN      NaN      NaN
# 1152787  CA     PERCENT  18-29  NaN      NaN      NaN
# 1152788  CA     PERCENT  18-29  NaN      NaN      NaN
# 1152789  CA     PERCENT  18-29  NaN      NaN      NaN
# 1152790  CA     PERCENT  18-29  NaN      NaN      NaN
# 1152791  CA     PERCENT  18-29  NaN      NaN      NaN
# 1152792  CA     PERCENT  18-29  NaN      NaN      NaN
# 1152793  CA     PERCENT  18-29  NaN      NaN      NaN
# 1152794  CA     PERCENT  18-29  NaN      NaN      NaN
#
#         [Education level] [Hazard type] [IHR Capacity] [Level/Status]  \
# 1822     NaN               NaN           NaN            NaN
# 1823     NaN               NaN           NaN            NaN
# 1824     NaN               NaN           NaN            NaN
# 1825     NaN               NaN           NaN            NaN
# 1826     NaN               NaN           NaN            NaN
# 1827     NaN               NaN           NaN            NaN
# 1828     NaN               NaN           NaN            NaN
# 1829     NaN               NaN           NaN            NaN
# 1830     NaN               NaN           NaN            NaN
# 1831     NaN               NaN           NaN            NaN
# 1832     NaN               NaN           NaN            NaN
# 1833     NaN               NaN           NaN            NaN
# 1834     NaN               NaN           NaN            NaN
# 1835     NaN               NaN           NaN            NaN
# 1836     NaN               NaN           NaN            NaN
# 1837     NaN               NaN           NaN            NaN
# 1838     NaN               NaN           NaN            NaN
# 1839     NaN               NaN           NaN            NaN
# 1840     NaN               NaN           NaN            NaN
# 1841     NaN               NaN           NaN            NaN
# 1842     NaN               NaN           NaN            NaN
# 1843     NaN               NaN           NaN            NaN
# 1152766  NaN                  NaN               NaN             NaN
# 1152767  NaN                  NaN               NaN             NaN
# 1152768  NaN                  NaN               NaN             NaN
# 1152769  NaN                  NaN               NaN             NaN
# 1152770  NaN                  NaN               NaN             NaN
# 1152771  NaN                  NaN               NaN             NaN
# 1152772  NaN                  NaN               NaN             NaN
# 1152773  NaN                  NaN               NaN             NaN
# 1152774  NaN                  NaN               NaN             NaN
# 1152775  NaN                  NaN               NaN             NaN
# 1152776  NaN                  NaN               NaN             NaN
# 1152777  NaN                  NaN               NaN             NaN
# 1152778  NaN                  NaN               NaN             NaN
# 1152779  NaN                  NaN               NaN             NaN
# 1152780  NaN                  NaN               NaN             NaN
# 1152781  NaN                  NaN               NaN             NaN
# 1152782  NaN                  NaN               NaN             NaN
# 1152783  NaN                  NaN               NaN             NaN
# 1152784  NaN                  NaN               NaN             NaN
# 1152785  NaN                  NaN               NaN             NaN
# 1152786  NaN                  NaN               NaN             NaN
# 1152787  NaN                  NaN               NaN             NaN
# 1152788  NaN                  NaN               NaN             NaN
# 1152789  NaN                  NaN               NaN             NaN
# 1152790  NaN                  NaN               NaN             NaN
# 1152791  NaN                  NaN               NaN             NaN
# 1152792  NaN                  NaN               NaN             NaN
# 1152793  NaN                  NaN               NaN             NaN
# 1152794  NaN                  NaN               NaN             NaN
#
# [141509 rows x 36 columns]

# %% [markdown]
# ## Replace column codes with full names
#
# Some dimension values in the dataset are codes like `EROSN` or `CHESP` which refer to _erosion_ and _chemical spill_, respectively. **Codelists** contain the mappings from **codes** → **full names**.
#
# The codelists can be retrieved from the SDGAPI: https://unstats.un.org/SDGAPI/swagger/#!/Goal/V1SdgGoalDataGet
#
# Specifically, the `GET /v1/sdg/Goal/Data` API call.

# %%
metadata = requests.get('https://unstats.un.org/SDGAPI/v1/sdg/Goal/Data').json()

# %% [markdown]
# There are codelists for dimensions (each column that is wrapped in `[]`) and codelists for the `Nature` and `Units` columns.

# %%
codelists_by_dimension_name = { 
    codelist['id']: { 
        row['code']: row['description'] for row in codelist['codes'] 
    } for codelist in metadata['dimensions'] 
}

# %%
codelists_by_column_name = { 
    codelist['id']: { 
        row['code']: row['description'] for row in codelist['codes'] 
    } for codelist in metadata['attributes'] 
}

# %% [markdown]
# #### Check which dataset dimensions we have codelists for
#
# There are currently no codelists for `Bounds`. We will have keep this in mind and avoid overwriting that column.

# %%
dimension_names = [c[1:-1] for c in original_df.columns if c[0] == '[' and c[-1] == ']']

# %%
comparison = pd.merge(
    pd.DataFrame({ 'dimensions': dimension_names }), 
    pd.DataFrame({ 'codelists': list(codelists_by_dimension_name.keys()) }), 
    left_on='dimensions', right_on='codelists', how='left')

comparison['match'] = comparison['dimensions'] == comparison['codelists']

# %%
comparison
# Out:
#                            dimensions                          codelists  \
# 0   Age                                Age
# 1   Bounds                             NaN
# 2   Cities                             Cities
# 3   Disability status                  Disability status
# 4   Education level                    Education level
# 5   Hazard type                        Hazard type
# 6   IHR Capacity                       IHR Capacity
# 7   Level/Status                       Level/Status
# 8   Location                           Location
# 9   Migratory status                   Migratory status
# 10  Mode of transportation             Mode of transportation
# 11  Name of international institution  Name of international institution
# 12  Name of non-communicable disease   Name of non-communicable disease
# 13  Quantile                           Quantile
# 14  Reporting Type                     Reporting Type
# 15  Sex                                Sex
# 16  Tariff regime (status)             Tariff regime (status)
# 17  Type of mobile technology          Type of mobile technology
# 18  Type of occupation                 Type of occupation
# 19  Type of product                    Type of product
# 20  Type of skill                      Type of skill
# 21  Type of speed                      Type of speed
#
#     match
# 0   True
# 1   False
# 2   True
# 3   True
# 4   True
# 5   True
# 6   True
# 7   True
# 8   True
# 9   True
# 10  True
# 11  True
# 12  True
# 13  True
# 14  True
# 15  True
# 16  True
# 17  True
# 18  True
# 19  True
# 20  True
# 21  True

# %% [markdown]
# #### Replace the codes for each column with the full names from the codelists

# %%
# Returns a dataframe with the dimension codes mapped to full names
def expand_codes(df, codelists_by_dimension_name, codelists_by_column_name):
    
    df = df.copy()
    dimension_names = [c[1:-1] for c in df.columns if c[0] == '[' and c[-1] == ']']
    codelist_names = list(codelists_by_dimension_name.keys())
    dimensions_to_remap = list(set(dimension_names) & set(codelist_names))
    
    # Remap the dimensions (the columns wrapped in [])
    for dim in dimensions_to_remap:
        col = '[' + dim + ']'
        df[col] = df[col].map(codelists_by_dimension_name[dim])
    
    column_names = [c for c in df.columns if c not in set(dimension_names)]
    codelist_names = list(codelists_by_column_name.keys())
    columns_to_remap = list(set(column_names) & set(codelist_names))
    
    # Remap the other columns (Nature & Units, and maybe others)
    for col in columns_to_remap:
        df[col] = df[col].map(codelists_by_column_name[col])
        
    return df

# %%
expanded_df = expand_codes(original_df, codelists_by_dimension_name, codelists_by_column_name)

# %% [markdown]
# #### Check that it was successful

# %%
expanded_df[['[Hazard type]']].drop_duplicates()
# Out:
#                      [Hazard type]
# 0      NaN
# 42075  Structural Collapse
# 42076  Storm
# 42077  Frost
# 42078  Avalanche
# 42079  Cold Wave
# 42080  Earthquake
# 42081  Wild Fire
# 42082  Windstorm
# 42083  Accident
# 42084  Hailstorm
# 42085  Heavy Rain
# 42086  Landslide
# 42087  Plague
# 42088  Sedimentation
# 42089  Electric Storm
# 42090  Epidemics
# 42091  Fire
# 42092  Flash Flood
# 42093  Flood
# 42094  Snowstorm
# 42118  Other
# 42136  Chemical Spill
# 42137  Coastal Flood
# 42138  Contamination
# 42195  Explosion
# 42203  Liquefaction
# 42230  Tsunami
# 42231  Cyclone
# 42244  Drought
# 42251  Erosion
# 42277  Tornado
# 42289  Extreme Temperature
# 42294  Pollution
# 42296  Coastal Erosion
# 42307  Biological
# 42331  Consolidate
# 42332  Heat Wave
# 42341  Alluvion
# 42348  Fog
# 42364  Epizootic
# 42409  Intoxication
# 42425  Volcanic Eruption
# 42557  Glacial Lake Outburst Flood
# 42611  Panic
# 42707  Animal Attack
# 42770  Subsidence
# 42778  Insect Infestation
# 43835  Lahar
# 44039  Deforestation
# 44900  Technological Hazard
# 44998  Sand Storm
# 45091  Freezing Rain
# 45372  Peat
# 45401  Pest
# 45789  Dzud
# 47309  Land Degradation
# 47852  Nuclear Incident
# 47960  Stuck
# 47961  Acid rain

# %%
expanded_df[['Units']].drop_duplicates()
# Out:
#                                                    Units
# 0        Percentage
# 40470    Index
# 40649    Number
# 42075    Millions of current United States dollars
# 50902    Per 100,000 population
# 58279    USD
# 89564    Thousands
# 95615    Millions
# 100660   % of children aged 0-59 months
# 101395   Millions of children aged 0-59 months
# 104640   Constant USD
# 141008   Per 100,000 live births
# 158042   Per 1,000 live births
# 210707   Per 1,000 uninfected population
# 244333   Per 1,000 population
# 282359   Litres pure alcohol
# 309395   Per 10,000 population
# 346035   Ratio
# 381747   % of married women aged 20-24 years
# 431814   United States dollars per cubic metre
# 433848   Square kilometers
# 433981   Million of cubic metres per annum
# 475753   Megajoules per USD constant 2011 PPP GDP
# 479785   Millions of constant 2015 United States dollars
# 496802   Tonnes
# 555531   Kilograms per constant USD
# 673423   Current local currency
# 701777   Per 100,000 employees
# 712791   Tonne kilometres
# 713399   Passenger kilometres
# 718744   Constant 2010 United States dollars
# 726490   Millions of tonnes
# 735737   Per million population
# 843183   Micrograms per cubic meter
# 1022965  Billions of current United States dollars
# 1064761  Thousands of hectares
# 1090161  Tonnes per hectare
# 1212359  Not applicable
# 1235852  Per 100 population

# %% [markdown]
# ## Export the geographical entities (countries & regions)
#
# Store all geographical entities (countries, regions & aggregates) in a separate file. They should be internally consistent within the dataset, but the final Our World in Data standardisation will happen in a later step.

# %%
entities = expanded_df[['GeoAreaCode', 'GeoAreaName']] \
    .sort_values(by='GeoAreaCode') \
    .drop_duplicates() \
    .rename(columns={'GeoAreaCode': 'id', 'GeoAreaName': 'name'})

# %%
entities.to_csv('./exported_data/entities.csv', index=False)

# %% [markdown]
# ## Export datasets and variables
#
# Algorithm outline:
#
#   - For each `INDICATOR`:
#     - Obtain dimensions (columns named `[between brackets]`) that contain non-null values
#       - For each combination of unique values values in those dimensions
#         - Generate a table of values.

# %%
DIMENSIONS = [c for c in expanded_df.columns if c[0] == '[' and c[-1] == ']']
NON_DIMENSIONS = [c for c in expanded_df.columns if c not in set(DIMENSIONS)]

@functools.lru_cache(maxsize=256)
def get_series_with_relevant_dimensions(indicator, series):
    """ For a given indicator and series, return a tuple:
    
      - data filtered to that indicator and series
      - names of relevant dimensions
      - unique values for each relevant dimension
    """
    data_filtered = expanded_df[(expanded_df.Indicator == indicator) & (expanded_df.SeriesCode == series)]
    non_null_dimensions_columns = [col for col in DIMENSIONS if data_filtered.loc[:, col].notna().any()]
    dimension_names = []
    dimension_unique_values = []
    
    for c in non_null_dimensions_columns:
        uniques = data_filtered[c].unique()
        if len(uniques) > 1:
            dimension_names.append(c)
            dimension_unique_values.append(list(uniques))

    return (data_filtered[NON_DIMENSIONS + dimension_names], dimension_names, dimension_unique_values)

# %% [markdown]
# Generate tables for:
#
#   - Rows where the dimension is `None`
#   - One table for each combination of unique values of relevant dimensions

# %%
@functools.lru_cache(maxsize=256)
def generate_tables_for_indicator_and_series(indicator, series):
    tables_by_combination = {}
    data_filtered, dimensions, dimension_values = get_series_with_relevant_dimensions(indicator, series)
    if len(dimensions) == 0:
        # no additional dimensions
        export = data_filtered
        return export
    else:
        for dimension_value_combination in itertools.product(*dimension_values):
            # build filter by reducing, start with a constant True boolean array
            filt = [True] * len(data_filtered)
            for dim_idx, dim_value in enumerate(dimension_value_combination):
                dimension_name = dimensions[dim_idx]
                value_is_nan = type(dim_value) == float and math.isnan(dim_value)
                filt = filt \
                       & (data_filtered[dimension_name].isnull() if value_is_nan else data_filtered[dimension_name] == dim_value)

            tables_by_combination[dimension_value_combination] = data_filtered[filt].drop(dimensions, axis=1)
            
        return tables_by_combination

# %%
all_series = expanded_df[['Indicator', 'SeriesCode', 'SeriesDescription', 'Units']] \
  .groupby(by=['Indicator', 'SeriesCode', 'SeriesDescription', 'Units']) \
  .count() \
  .reset_index()

# %% [markdown]
# ### Export data
#
# For each series and combination of additional dimensions' members, generate an entry in the `variables` table.

# %%
datasets = pd.DataFrame(columns=['id', 'name'])
variables = pd.DataFrame(columns=['id', 'name', 'unit', 'dataset_id'])
sources = pd.DataFrame(columns=['id', 'name', 'description', 'dataset_id'])

source_description_template = {
    'dataPublishedBy': "United Nations Statistics Division",
    'dataPublisherSource': None,
    'link': "https://unstats.un.org/sdgs/indicators/database/",
    'retrievedDate': datetime.now().strftime("%d-%B-%y"),
    'additionalInfo': None
}

variable_idx = 0

def extract_datapoints(df):
    return pd.DataFrame({
        'entity': df['GeoAreaCode'],
        'year': df['TimePeriod'],
        'value': df['Value']
    }).drop_duplicates(subset=['entity', 'year']).dropna()

for i, row in tqdm(all_series.iterrows(), total=len(all_series)):
    
    # DATASET
    
    datasets = datasets.append(
        {
            'id': i, 
            'name': row['SeriesDescription']
        }, 
        ignore_index=True)
    

    # SOURCE
    
    source_description = source_description_template.copy()
    
    try:
        source_description['additionalInfo'] = extract_description('metadata/Metadata-%s.pdf' % '-'.join([part.rjust(2, '0') for part in row['Indicator'].split('.')]))
    except:
        pass
    
    sources = sources.append({
        'id': i,
        'name': "%s (UN SDG, 2019)" % row['SeriesDescription'],
        'description': json.dumps(source_description),
        'dataset_id': i
    }, ignore_index=True)
        

    # VARIABLES & DATAPOINTS
    
    _, dimensions, dimension_members = get_series_with_relevant_dimensions(row['Indicator'], row['SeriesCode'])
    
    if len(dimensions) == 0:
        # no additional dimensions
        table = generate_tables_for_indicator_and_series(row['Indicator'], row['SeriesCode'])
        variable = {
            'id': variable_idx,
            'dataset_id': i,
            'unit': row['Units'],
            'name': "%s - %s - %s" % (row['Indicator'], row['SeriesDescription'], row['SeriesCode'])
        }
        variables = variables.append(variable, ignore_index=True)
        extract_datapoints(table).to_csv('./exported_data/%04d_datapoints.csv' % variable_idx, index=False)
        variable_idx += 1

    else:
        # has additional dimensions
        for member_combination, table in generate_tables_for_indicator_and_series(row['Indicator'], row['SeriesCode']).items():
            variable = {
                'id': variable_idx,
                'dataset_id': i,
                'unit': row['Units'],
                'name': "%s - %s - %s - %s" % (
                    row['Indicator'], 
                    row['SeriesDescription'], 
                    row['SeriesCode'],
                    ' - '.join(map(str, member_combination)))
                
            }
            variables = variables.append(variable, ignore_index=True)
            extract_datapoints(table).to_csv('./exported_data/%04d_datapoints.csv' % variable_idx, index=False)
            variable_idx += 1


variables.to_csv('./exported_data/variables.csv', index=False)
datasets.to_csv('./exported_data/datasets.csv', index=False)
sources.to_csv('./exported_data/sources.csv', index=False)
# Out:
#   8%|▊         | 34/447 [00:24<06:37,  1.04it/s]
